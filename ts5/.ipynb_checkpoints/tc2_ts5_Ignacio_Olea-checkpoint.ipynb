# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# ### Teoría de Circuitos II
#
# # Trabajo Semanal N°5
#
# Autor: *Olea Gasalla Ignacio Ezequiel*

# %% [markdown]
# *Fecha de entrega: lunes 6 de julio de 2026*

# %% [markdown]
# #### **Consigna**
# <img src="./consigna_1.png" />
#
# ##### **Bonus**:
# <img src="./consigna_2.png" />
# <img src="./consigna_3.png" />
#
# ##### **Anexo**:
# 📎 En caso de no poder acceder al documento, presione aquí: [Mostrar PDF](./tc2_ts5.pdf)

# %%
from IPython.display import IFrame
IFrame("./tc2_ts5.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./tc2_ts5.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Gran parte de la tarea semanal está resuelta en el documento superior, allí se muestra la obtención de los parametros para los circuitos pedidos: Para el circuito "Tee" se calculó sus parámetros Z; para el circuito "Pi", se calculó sus parámetros Y; y para el circuito "Lattice" se calcularon sus parámetros T (Tabcd).
#
# Luego de calcular las matrices, en una página se escriben las reglas de transformación (ej: Z->T implica que se pasó de una matriz Z a una matriz T) y, acto seguido, la matriz a la que se quizo llegar. Se tomó la libertad de sacar de la matriz los terminos en común y se mantuvieron los terminos "largos" (como los determinantes) escritos por separado para tener una mejor lectura.

# %% [markdown]
# #### **Bonús**

# %% [markdown]
# 1. Para el primer bonús no se logró acceder al cuestionario por lo que no pudo ser realizado.

# %% [markdown]
# 2. En caso de la red circuital, se usó la que se muestra en el ejemplo dado:
#
#
#    <img src="./circuit.png" />
#
#    Y se llegó a un ploteo de los parámetros Z consistente a lo mostrado en el ejemplo:
#
#    <img src="./plot_Z.png" />
#
#    Junto con el ploteo de los parámetros Y:
#
#    <img src="./plot_Y.png" />
#
#     En el caso del ploteo de Z, los parámetros $Z_{12}$ y $Z_{21}$ están solapados, lo cual tiene sentido ya que la red es resíproca. En el ploteo del Y sucede lo mismo pero con $Y_{12}$ y $Y_{21}$. Tanto la matriz Z como la Y son correspondientes con los resultados por definición de la "Tee" como el resultado por transformación a la Y.

# %% [markdown]
# 3. Este punto fue realizado en la ultima página del documento. Cabe aclarar que se usó el modelo de transformador ideal ya que no se aclara cual se debería usar se utilizó el que permitía más simplicidad, para el caso, el transformador no tiene relación de transconductancia y transimpedancia por lo que los parámetros B y C son igual a 0. Mientras que si presenta variación ante una excitación de tensión en la tensión de salida y, asi mismo, ocurre con la corriente de entrada, generando variación en la corriente de salida. Esta variación (ganancia o atenuación) depende de la constante del transformador.
